# %%
from bs4 import BeautifulSoup
import requests
import pymongo
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager
from flask import Flask, render_template, redirect
import pandas as pd

# %% [markdown]
# # NASA Mars News

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [/Users/josephneff/.wdm/drivers/chromedriver/mac64/99.0.4844.51/chromedriver] found in cache

# %%
url = 'https://redplanetscience.com/'
browser.visit(url)


html = browser.html
soup = BeautifulSoup(html, 'html.parser')

news_title = soup.find("div", class_="content_title").text
news_title

news_p = soup.find("div", class_= "article_teaser_body").text
news_p

browser.quit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/tb/284z5t112fdcqbwthgkr8gx40000gp/T/ipykernel_84119/845140957.py in <module>
#       4
#       5 html = browser.html
# ----> 6 soup = BeautifulSoup(html, 'html.parser')
#       7
#       8 news_title = soup.find("div", class_="content_title").text
#
# ~/opt/anaconda3/lib/python3.9/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     310         if hasattr(markup, 'read'):        # It's a file-type object.
#     311             markup = markup.read()
# --> 312         elif len(markup) <= 256 and (
#     313                 (isinstance(markup, bytes) and not b'<' in markup)
#     314                 or (isinstance(markup, str) and not '<' in markup)
#
# TypeError: object of type 'NoneType' has no len()

# %% [markdown]
# # JPL Mars Space Images - Featured Image

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

img_url = "https://spaceimages-mars.com/"
browser.visit(img_url)

html = browser.html
soup = BeautifulSoup(html, 'lxml')

relative_image_path = soup.find_all('img')[1]["src"]
relative_image_path

featured_image_url = img_url + relative_image_path
featured_image_url

browser.quit()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [/Users/josephneff/.wdm/drivers/chromedriver/mac64/99.0.4844.51/chromedriver] found in cache
# 'https://spaceimages-mars.com/image/featured/mars1.jpg'

# %% [markdown]
# # Mars Facts

# %%
table_url = "https://galaxyfacts-mars.com/"
tables = pd.read_html(table_url)
tables
# Out:
# [                         0                1                2
#  0  Mars - Earth Comparison             Mars            Earth
#  1                Diameter:         6,779 km        12,742 km
#  2                    Mass:  6.39 × 10^23 kg  5.97 × 10^24 kg
#  3                   Moons:                2                1
#  4       Distance from Sun:   227,943,824 km   149,598,262 km
#  5          Length of Year:   687 Earth days      365.24 days
#  6             Temperature:     -87 to -5 °C      -88 to 58°C,
#                        0                              1
#  0  Equatorial Diameter:                       6,792 km
#  1       Polar Diameter:                       6,752 km
#  2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
#  3                Moons:          2 ( Phobos & Deimos )
#  4       Orbit Distance:       227,943,824 km (1.38 AU)
#  5         Orbit Period:           687 days (1.9 years)
#  6  Surface Temperature:                   -87 to -5 °C
#  7         First Record:              2nd millennium BC
#  8          Recorded By:           Egyptian astronomers]

# %%
facts_df = tables[0]
facts_df
# Out:
#                          0                1                2
# 0  Mars - Earth Comparison             Mars            Earth
# 1                Diameter:         6,779 km        12,742 km
# 2                    Mass:  6.39 × 10^23 kg  5.97 × 10^24 kg
# 3                   Moons:                2                1
# 4       Distance from Sun:   227,943,824 km   149,598,262 km
# 5          Length of Year:   687 Earth days      365.24 days
# 6             Temperature:     -87 to -5 °C      -88 to 58°C

# %%
html_table = facts_df.to_html()
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>0</th>\n      <th>1</th>\n      <th>2</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Mars - Earth Comparison</td>\n      <td>Mars</td>\n      <td>Earth</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Diameter:</td>\n      <td>6,779 km</td>\n      <td>12,742 km</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Mass:</td>\n      <td>6.39 × 10^23 kg</td>\n      <td>5.97 × 10^24 kg</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>Moons:</td>\n      <td>2</td>\n      <td>1</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>Distance from Sun:</td>\n      <td>227,943,824 km</td>\n      <td>149,598,262 km</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>Length of Year:</td>\n      <td>687 Earth days</td>\n      <td>365.24 days</td>\n    </tr>\n    <tr>\n      <th>6</th>\n      <td>Temperature:</td>\n      <td>-87 to -5 °C</td>\n      <td>-88 to 58°C</td>\n    </tr>\n  </tbody>\n</table>'

# %% [markdown]
# # Mars Hemispheres

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [/Users/josephneff/.wdm/drivers/chromedriver/mac64/99.0.4844.51/chromedriver] found in cache

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

hemispheres_url = "https://marshemispheres.com/"
browser.visit(hemispheres_url)

html = browser.html
soup = BeautifulSoup(html, 'lxml')
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [/Users/josephneff/.wdm/drivers/chromedriver/mac64/99.0.4844.51/chromedriver] found in cache

# %%
hemisphere_img_urls = []

names = ["Cerberus", "Schiaparelli", "Syrtis", "Valles"]
for name in names:
    browser.find_by_tag("a").links.find_by_partial_text(name).click()

    html = browser.html
    soup = BeautifulSoup(html, 'lxml')

    hemi_title = soup.find("h2", class_="title").text
    title = hemi_title.replace("Enhanced", "")
    print(title)

    img = soup.find("div", class_="downloads")
    image_url = img.find_all('a')[0]["href"]
    img_url = hemispheres_url + image_url
    print(img_url)
    
    hemisphere_img_urls.append({"Title": title, "Image URL": img_url})
    
    browser.links.find_by_partial_text('Back').click()
    time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# /var/folders/tb/284z5t112fdcqbwthgkr8gx40000gp/T/ipykernel_84119/93986999.py in <module>
#       3 names = ["Cerberus", "Schiaparelli", "Syrtis", "Valles"]
#       4 for name in names:
# ----> 5     browser.find_by_tag("a").links.find_by_partial_text(name).click()
#       6
#       7     html = browser.html
#
# ~/opt/anaconda3/lib/python3.9/site-packages/splinter/driver/webdriver/__init__.py in find_by_tag(self, tag, wait_time)
#     558
#     559     def find_by_tag(self, tag, wait_time=None):
# --> 560         return self.find_by(
#     561             self.driver.find_elements_by_tag_name,
#     562             tag,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/splinter/driver/webdriver/__init__.py in find_by(self, finder, selector, original_find, original_query, wait_time)
#     272
#     273         while time.time() < end_time:
# --> 274             elem_list = _find(self, finder, selector)
#     275
#     276             if elem_list:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/splinter/driver/webdriver/__init__.py in _find(self, finder, selector)
#     231
#     232     try:
# --> 233         elements = finder(selector)
#     234         if not isinstance(elements, list):
#     235             elements = [elements]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in find_elements_by_tag_name(self, name)
#     734             stacklevel=2,
#     735         )
# --> 736         return self.find_elements(by=By.TAG_NAME, value=name)
#     737
#     738     def find_element_by_class_name(self, name) -> WebElement:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in find_elements(self, by, value)
#    1281         # Return empty list if driver returns null
#    1282         # See https://github.com/SeleniumHQ/selenium/issues/4555
# -> 1283         return self.execute(Command.FIND_ELEMENTS, {
#    1284             'using': by,
#    1285             'value': value})['value'] or []
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     423         response = self.command_executor.execute(driver_command, params)
#     424         if response:
# --> 425             self.error_handler.check_response(response)
#     426             response['value'] = self._unwrap_value(
#     427                 response.get('value', None))
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchWindowException: Message: no such window: window was already closed
#   (Session info: chrome=99.0.4844.51)
# Stacktrace:
# 0   chromedriver                        0x000000010527f159 chromedriver + 5120345
# 1   chromedriver                        0x000000010520cb13 chromedriver + 4651795
# 2   chromedriver                        0x0000000104dfce68 chromedriver + 392808
# 3   chromedriver                        0x0000000104dec23e chromedriver + 324158
# 4   chromedriver                        0x0000000104ded762 chromedriver + 329570
# 5   chromedriver                        0x0000000104de5ffc chromedriver + 299004
# 6   chromedriver                        0x0000000104dfe2b2 chromedriver + 398002
# 7   chromedriver                        0x0000000104e61db2 chromedriver + 806322
# 8   chromedriver                        0x0000000104e4fa33 chromedriver + 731699
# 9   chromedriver                        0x0000000104e255dd chromedriver + 558557
# 10  chromedriver                        0x0000000104e264f5 chromedriver + 562421
# 11  chromedriver                        0x000000010523c38d chromedriver + 4846477
# 12  chromedriver                        0x000000010525621c chromedriver + 4952604
# 13  chromedriver                        0x000000010525ba12 chromedriver + 4975122
# 14  chromedriver                        0x0000000105256b4a chromedriver + 4954954
# 15  chromedriver                        0x00000001052315b0 chromedriver + 4801968
# 16  chromedriver                        0x0000000105270f78 chromedriver + 5062520
# 17  chromedriver                        0x00000001052710ff chromedriver + 5062911
# 18  chromedriver                        0x0000000105286545 chromedriver + 5150021
# 19  libsystem_pthread.dylib             0x00007fff2045e8fc _pthread_start + 224
# 20  libsystem_pthread.dylib             0x00007fff2045a443 thread_start + 15

# %%
hemisphere_img_urls
# Out:
# []

# %%
browser.quit()
